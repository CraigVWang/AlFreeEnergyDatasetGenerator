# %%
from main import AlchemicalDataGenerator
import hydra
from omegaconf import OmegaConf

# Set the function to load and override config.
def load_config(overrides=[]):
    with hydra.initialize(version_base=None, config_path="./config/"):
        return hydra.compose(
            config_name="base.yaml", overrides=overrides
            )

conf = load_config(overrides=[])
print(OmegaConf.to_yaml(conf))

exp = AlchemicalDataGenerator(conf)
exp.run_single_test()
# Out:
# Warning on use of the timeseries module: If the inherent timescales of the system are long compared to those being analyzed, this statistical inefficiency may be an underestimate.  The estimate presumes the use of many statistically independent samples.  Tests should be performed to assess whether this condition is satisfied.   Be cautious in the interpretation of the data.
#
# ****** PyMBAR will use 64-bit JAX! *******
# * JAX is currently set to 32-bit bitsize *
# * which is its default.                  *
# *                                        *
# * PyMBAR requires 64-bit mode and WILL   *
# * enable JAX's 64-bit mode when called.  *
# *                                        *
# * This MAY cause problems with other     *
# * Uses of JAX in the same code.          *
# ******************************************
# experiment:
#   name: 炼金术数据生成实验
#   description: 执行完整的自由能微扰数据生成流程
# input:
#   data_dir: ./dataset/raw
#   preparation_dir: ${output.base_dir}/prepared_systems
#   alchemical_dir: ${output.base_dir}/alchemical_results
# output:
#   base_dir: ./dataset
#   preprocessed_dir: ${output.base_dir}/preprocessed
#   metadata_dir: ${output.base_dir}/metadata
#   prepared_dir: ${output.base_dir}/prepared_systems
#   alchemical_dir: ${output.base_dir}/alchemical_results
#   analysis_dir: ${output.base_dir}/analysis_results
# logging:
#   level: INFO
#   format: '%(asctime)s - %(name)s - %(levelname)s - %(message)s'
#   file: ${output.base_dir}/logs/experiment.log
# mode: full
# test_single: false
# selected_formats: null
# dataset:
#   raw_directory: ${input.data_dir}
#   preprocessed_directory: ${output.preprocessed_dir}
#   metadata_directory: ${output.metadata_dir}
#   supported_formats:
#   - .pdb
#   - .cif
#   - .mol2
#   - .sdf
#   - .xyz
#   conversion:
#     default_output_format: pdb
#     xyz_converter:
#       auto_optimize: true
#       max_optimization_attempts: 5
#       residue_name: MOL
#       chain_id: A
#   pdb_processing:
#     remove_heteroatoms: false
#     preserve_original_structure: true
#   validation:
#     check_bond_lengths: true
#     check_formal_charges: true
#     max_bond_length: 3.0
#     min_bond_length: 0.5
#   batch_processing:
#     max_workers: 4
#     batch_size: 10
# preparation:
#   forcefield:
#     files:
#     - amber14/protein.ff14SB.xml
#     - amber14/tip3p.xml
#     use_gaff: true
#   system:
#     add_hydrogens: true
#     nonbonded_method: PME
#     cutoff: 1.0
#     constraints: HBonds
#     rigid_water: true
#     ewald_error_tolerance: 0.0005
#     centering_threshold: 0.1
#   solvent:
#     model: tip3p
#     box_size: 8.0
#     padding: null
#     positive_ion: Na+
#     negative_ion: Cl-
#     ionic_strength: 0.0
#   integrator:
#     temperature: 300.0
#     friction_coeff: 1.0
#     time_step: 2.0
#   platform:
#     use_cuda: true
#     device_index: '0'
#     precision: mixed
#   minimization:
#     max_iterations: 1000
#     tolerance: 10.0
#   heating:
#     initial_temperature: 50.0
#     target_temperature: 300.0
#     temperature_step: 50.0
#     steps_per_temperature: 5000
#   equilibration:
#     use_barostat: true
#     pressure: 1.0
#     barostat_frequency: 25
#     npt_steps: 50000
#   metadata_file: ./dataset/metadata.csv
# alchemical:
#   temperature: 300.0
#   time_step: 0.1
#   collision_rate: 5.0
#   total_iterations: 50
#   steps_per_iteration: 50
#   checkpoint_interval: 10
#   lambda_schedule:
#     segments:
#     - - 1.0
#       - 0.95
#       - 8
#     - - 0.95
#       - 0.8
#       - 12
#     - - 0.8
#       - 0.5
#       - 12
#     - - 0.5
#       - 0.2
#       - 12
#     - - 0.2
#       - 0.0
#       - 12
#   platform:
#     name: CUDA
#     precision: mixed
#   factory:
#     type: AbsoluteAlchemicalFactory
#   sampler:
#     type: ReplicaExchangeSampler
#     replica_mixing_scheme: swap-neighbors
# analysis:
#   plot_format: png
#   plot_dpi: 300
#   figure_size:
#   - 10
#   - 8
#   convergence_threshold: 0.1
#   sampling_sufficiency_threshold: 50
#   free_energy:
#     reference_state: 0
#     target_state: -1
#   convergence:
#     burn_in_fraction: 0.1
#     statistical_inefficiency_method: timeseries
#   visualization:
#     show_replica_trajectories: true
#     show_energy_timeseries: true
#     show_free_energy_profile: true
#
# 🧪 开始单个样本测试流程
# ============================================================
# 🎯 开始炼金术数据生成完整流程
# 🧪 测试模式：只处理单个样本
# 📝 实验名称: 炼金术数据生成实验
# 📋 实验描述: 执行完整的自由能微扰数据生成流程
# ============================================================
# 🚀 开始数据预处理阶段
# 🧪 测试模式：只处理单个样本
# ============================================================
# 📂 目录设置完成:
#    - 原始数据目录: ./dataset/raw
#    - 预处理目录: ./dataset/preprocessed
#    - 元数据目录: ./dataset/metadata
#    - 元数据文件: dataset/metadata/metadata.csv
#    - 选定格式: 所有支持格式
# ============================================================
# 🚀 开始结构文件预处理流程
# 🧪 测试模式：只处理单个样本
# ============================================================
# 📖 读取现有元数据文件: dataset/metadata/metadata.csv
# 🔍 处理所有支持格式的文件
# 📁 开始扫描目录: ./dataset/raw
# 📂 扫描文件: 100%|██████████| 641/641 [00:00<00:00, 50435.19it/s]
# ✅ 找到 639 个分子（1 个现有 + 638 个新）
#
# 🔄 开始批量处理文件...
# 🧪 测试模式：只处理第一个分子: i060
# 🔄 处理文件: 100%|██████████| 1/1 [00:00<00:00, 1738.21it/s, 跳过: 0/1]
# 📊 成功处理 0/1 个文件
# 💾 元数据已保存到: dataset/metadata/metadata.csv
#
# 📈 文件类型统计:
#    - xyz: 1 个文件
# 🔍 找到 0 个可能的PDB ID
#
# 📊 处理状态统计:
#    - 总分子数: 1
#    - 预处理成功: 1 (100.0%)
#    - 系统准备成功: 0 (0.0%)
#    - 炼金术成功: 0 (0.0%)
#    - 分析成功: 0 (0.0%)
#    - 完成全部流程: 0 (0.0%)
# ============================================================
# 🎉 结构文件预处理完成!
# ============================================================
# 📖 加载元数据: 1 个分子
# ✅ 数据预处理阶段完成
# ============================================================
# 🔬 开始系统准备阶段
# 🧪 测试模式：只处理单个样本
# ============================================================
# 📖 加载元数据: 1 个分子
# 📁 创建系统准备输出目录: dataset/prepared_systems
# ============================================================
# 🚀 开始分子系统准备流程
# ⚙️ 使用配置:
#    - 盒子大小: 8.0 nm
#    - 溶剂模型: tip3p
#    - 温度: 300.0 K
#    - 时间步长: 2.0 fs
#    - 使用GPU: True
# 🧪 测试模式：只处理单个样本
# ============================================================
# 📖 读取到 1 个分子信息
# 🧪 测试模式：只处理第一个分子: i060
# 🧪 注意：测试模式使用与完整模式相同的系统和参数配置
# 🔍 找到 1 个需要处理的分子
# 🔄 系统准备:   0%|          | 0/1 [00:00<?, ?it/s]Traceback (most recent call last):
#   File "/mnt/WorkSpace/AlFreeEnergyDatasetGenerator/system_provider.py", line 454, in prepare_single_system
#     system, modeller, ligand_atom_count = self.prepare_system(
#                                           ^^^^^^^^^^^^^^^^^^^^
#   File "/mnt/WorkSpace/AlFreeEnergyDatasetGenerator/system_provider.py", line 211, in prepare_system
#     modeller.addSolvent(
#   File "/home/craigv/micromamba/envs/openff-env/lib/python3.11/site-packages/openmm/app/modeller.py", line 458, in addSolvent
#     raise ValueError('At most one of the following arguments may be specified: boxSize, boxVectors, padding, numAdded')
# ValueError: At most one of the following arguments may be specified: boxSize, boxVectors, padding, numAdded
# 🔄 系统准备: 100%|██████████| 1/1 [00:00<00:00, 16.93it/s, 成功: 0/1]
# 🔬 准备分子系统: i060
#   📁 文件: dataset/preprocessed/MNSol/water/i060.pdb
#   ⚠️ 创建分子对象失败，使用默认力场: No toolkits in registry can read file dataset/preprocessed/MNSol/water/i060.pdb (format PDB). Supported formats in the provided ToolkitRegistry are {'OpenFF NAGL': [], 'The RDKit': ['SDF', 'MOL', 'SMI'], 'AmberTools': [], 'Built-in Toolkit': []}. RDKit can not safely read PDBs on their own. Information about bond order and aromaticity is likely to be lost. PDBs can be used along with a valid smiles string with RDKit using the constructor Molecule.from_pdb_and_smiles(file_path, smiles)
#   ➕ 添加氢原子...
#   ⚠️ 添加氢原子时出现问题: No template found for residue 0 (MOL).  The set of atoms is similar to CALA, but is missing 1 N atom.  For more information, see https://github.com/openmm/openmm/wiki/Frequently-Asked-Questions#template
#   ⚠️ 继续处理，可能氢原子已存在
#   💧 添加溶剂...
# ❌ 准备分子系统 i060 失败: At most one of the following arguments may be specified: boxSize, boxVectors, padding, numAdded
#   📝 更新分子状态: i060 - preparation = 失败
#
# 📊 准备完成:
#    - 总处理: 1
#    - 成功准备: 0
#    - 成功率: 0.0%
# 💾 元数据已保存到: dataset/metadata/metadata.csv
# ✅ 系统准备阶段完成
# ============================================================
# 🧪 开始炼金术自由能模拟阶段
# 🧪 测试模式：只处理单个样本
# ============================================================
# ⚠️  没有找到内存中的准备结果，尝试从文件加载...
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[1], line 16
#      13 print(OmegaConf.to_yaml(conf))
#      15 exp = AlchemicalDataGenerator(conf)
# ---> 16 exp.run_single_test()
#
# File /mnt/WorkSpace/AlFreeEnergyDatasetGenerator/main.py:396, in AlchemicalDataGenerator.run_single_test(self, selected_formats)
#     393 print("=" * 60)
#     395 # 运行完整流程，但只处理一个样本
# --> 396 self.run_full_pipeline(selected_formats, test_single=True)
#     398 print("=" * 60)
#     399 print("🧪 单个样本测试完成!")
#
# File /mnt/WorkSpace/AlFreeEnergyDatasetGenerator/main.py:380, in AlchemicalDataGenerator.run_full_pipeline(self, selected_formats, test_single)
#     377 self.prepare_systems(test_single)
#     379 # 阶段3: 炼金术模拟
# --> 380 self.run_alchemical_simulation(test_single)
#     382 # 阶段4: 结果分析
#     383 self.analyze_results(test_single)
#
# File /mnt/WorkSpace/AlFreeEnergyDatasetGenerator/main.py:299, in AlchemicalDataGenerator.run_alchemical_simulation(self, test_single)
#     296 results_file = preparation_dir / "preparation_results.pkl"
#     298 if not results_file.exists():
# --> 299     raise Exception(f"❌ 未找到准备结果文件: {results_file}")
#     301 try:
#     302     with open(results_file, 'rb') as f:
#
# Exception: ❌ 未找到准备结果文件: dataset/prepared_systems/preparation_results.pkl
